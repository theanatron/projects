# %% [markdown]
# # Could Brazil have won the World Cup?

# %% [markdown]
# In this project, we'll determine if Brazil could have won the 2022 FIFA World Cup in Qatar.
#
# **Project Steps**
# - Clean data and prepare it for machine learning using pandas
# - Make predictions on the outcome of Brazil's matches using scikit-learn
# - Measure error and improve our predictions
# - Make predictions using future matches
#
# Data by FBref

# %% [markdown]
# ### Predicting the Outcome of Matches

# %%
import pandas as pd

# %%
#Calling our two data files

matches = pd.read_table('brazil_matches.csv', sep = ',' )
future_matches = pd.read_table('brazil_future_matches.csv', sep = ',' )
matches.head(10)
# Out:
#    Year      Date           Time Comp               Round  Day Venue Result  \
# 0  2020   10/9/20  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 1  2020  10/13/20  19:00 (02:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 2  2020  11/13/20  21:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 3  2020  11/17/20  20:00 (00:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 4  2021    6/4/21  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 5  2021    6/8/21  20:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 6  2021    9/2/21  21:00 (03:00)  WCQ  WCQ — CONMEBOL (M)  Thu  Away      W
# 7  2021    9/5/21  16:00 (21:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Home      D
# 8  2021    9/9/21  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Thu  Home      W
# 9  2021   10/7/21  19:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Thu  Away      W
#
#    GF  GA  GD KTPM Opponent Attendance       Captain Formation  \
# 0   5   0   5  NaN      BOL        NaN      Casemiro    4/3/03
# 1   4   2   2  NaN      PER        NaN  Thiago Silva    4/3/03
# 2   1   0   1  NaN      VEN        NaN  Thiago Silva    4/3/03
# 3   2   0   2  NaN      URU        NaN  Thiago Silva    4/3/03
# 4   2   0   2  NaN      ECU        NaN      Casemiro    4/3/03
# 5   2   0   2  NaN      PAR        NaN    Marquinhos   4-2-2-2
# 6   1   0   1  NaN      CHI        NaN      Casemiro    4/4/02
# 7   0   0   0  NaN      ARG        NaN      Casemiro   4-2-2-2
# 8   2   0   2  NaN      PER        NaN      Casemiro    4/4/02
# 9   3   1   2  NaN      VEN        NaN  Thiago Silva    4/4/02
#
#             Referee Coach
# 0   Leodán González  Tite
# 1    Julio Bascuñán  Tite
# 2      Juan Benítez  Tite
# 3     Roberto Tobar  Tite
# 4    Alexis Herrera  Tite
# 5  Patricio Loustau  Tite
# 6        Diego Haro  Tite
# 7  Jesús Valenzuela  Tite
# 8     Wilmar Roldán  Tite
# 9      Kevin Ortega  Tite

# %%
future_matches
# Out:
#    Year  Date  Time Comp        Round  Day    Venue  Result  GF  GA  GD  KTPM  \
# 0  2022   NaN   NaN  FWC  Semi-finals  NaN  Neutral     NaN NaN NaN NaN   NaN
# 1  2022   NaN   NaN  FWC        Final  NaN  Neutral     NaN NaN NaN NaN   NaN
# 2  2023   NaN   NaN  FRL     Friendly  NaN     Away     NaN NaN NaN NaN   NaN
#
#   Opponent  Attendance  Captain  Formation  Referee Coach
# 0      ARG         NaN      NaN        NaN      NaN  Tite
# 1      FRA         NaN      NaN        NaN      NaN  Tite
# 2      MAR         NaN      NaN        NaN      NaN   New

# %%
#Checking dtype
matches.dtypes
# Out:
# Year           int64
# Date          object
# Time          object
# Comp          object
# Round         object
# Day           object
# Venue         object
# Result        object
# GF             int64
# GA             int64
# GD             int64
# KTPM          object
# Opponent      object
# Attendance    object
# Captain       object
# Formation     object
# Referee       object
# Coach         object
# dtype: object

# %%
#Reviewing our Opponent Sample
count_rival = pd.DataFrame(pd.value_counts(matches.Opponent))
count_rival.head()
# Out:
#      Opponent
# PER        10
# ARG         9
# COL         8
# VEN         7
# URU         6

# %%
#Reviewing our Number of Matches Sample
count_matches = pd.DataFrame(pd.value_counts(matches.Year))
count_matches.head()
# Out:
#       Year
# 2021    27
# 2019    16
# 2018    14
# 2022    13
# 2016     8

# %%
#Converting Opponent, Year, and Comp as a Catergory Code
matches['opp_code'] = matches['Opponent'].astype('category').cat.codes
matches['year_code'] = matches['Year'].astype('category').cat.codes
matches['kind_code'] = matches['Comp'].astype('category').cat.codes
matches['target'] = (matches['Result'] == 'W').astype('int')

# %%
matches.head(5)
# Out:
#    Year      Date           Time Comp               Round  Day Venue Result  \
# 0  2020   10/9/20  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 1  2020  10/13/20  19:00 (02:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 2  2020  11/13/20  21:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 3  2020  11/17/20  20:00 (00:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 4  2021    6/4/21  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
#
#    GF  GA  ...  Opponent Attendance       Captain Formation          Referee  \
# 0   5   0  ...       BOL        NaN      Casemiro    4/3/03  Leodán González
# 1   4   2  ...       PER        NaN  Thiago Silva    4/3/03   Julio Bascuñán
# 2   1   0  ...       VEN        NaN  Thiago Silva    4/3/03     Juan Benítez
# 3   2   0  ...       URU        NaN  Thiago Silva    4/3/03    Roberto Tobar
# 4   2   0  ...       ECU        NaN      Casemiro    4/3/03   Alexis Herrera
#
#   Coach opp_code year_code  kind_code  target
# 0  Tite        3         5          3       1
# 1  Tite       21         5          3       1
# 2  Tite       31         5          3       1
# 3  Tite       29         5          3       1
# 4  Tite       10         6          3       1
#
# [5 rows x 22 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#Identifying our Training and Test Data
train = matches[matches['Year'] < 2021]
test = matches[matches['Year'] >= 2022]
predictors = ['kind_code','year_code','opp_code']

# %%
#Fitting the Training Data into the Classifier
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#Defining preds
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
#Checking our accuracy_score
accuracy_score(test['target'], preds)
# Out:
# 0.7692307692307693

# %%
#Combing the actual and predicted outcomes into a df
combined = pd.DataFrame(dict(actual = test['target'], prediction = preds))
pd. crosstab(index=combined['actual'], columns = combined['prediction'])
# Out:
# prediction   1
# actual
# 0            3
# 1           10

# %%
from sklearn.metrics import precision_score

# %%
#Checking our precision_score
precision_score(test['target'], preds)
# Out:
# 0.7692307692307693

# %%
#Grouping Matches
grouped_matches = matches.groupby('Coach')
group = grouped_matches.get_group('Tite').sort_values('Date')

# %%
#Defining our rolling averages for GF, GA, and GD
def rolling_averages(group, cols, new_cols):
  group = group.sort_values('Date')
  rolling_stats = group[cols].rolling(1, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group
  
cols = ['GF','GA','GD']
new_cols = [f'{c}_rolling' for c in cols]

rolling_averages(group, cols, new_cols).head()
# Out:
#     Year      Date           Time Comp               Round  Day Venue Result  \
# 77  2017  10/10/17  20:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Tue  Home      W
# 56  2019  10/10/19  20:00 (14:00)  FRL      Friendlies (M)  Thu  Home      D
# 10  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 40  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 69  2016  10/11/16  20:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
#
#     GF  GA  ...  Formation                Referee Coach opp_code year_code  \
# 77   3   0  ...        NaN             Juan Bravo  Tite        5         2
# 56   1   1  ...    4-2-2-2  Taqi Aljaafari Jahari  Tite       24         4
# 10   0   0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 40   0   0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 69   2   0  ...        NaN        Víctor Carrillo  Tite       31         1
#
#    kind_code target GF_rolling  GA_rolling  GD_rolling
# 77         3      1        1.0         1.0         0.0
# 56         1      0        3.0         0.0         3.0
# 10         3      0        1.0         1.0         0.0
# 40         3      0        0.0         0.0         0.0
# 69         3      1        0.0         0.0         0.0
#
# [5 rows x 25 columns]

# %%
#Grouping our rolling averages 
matches_rolling = matches.groupby('Opponent').apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('Opponent')
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling.head()
# Out:
#    Year      Date           Time Comp               Round  Day    Venue  \
# 0  2015  11/13/15  21:00 (01:00)  WCQ  WCQ — CONMEBOL (M)  Fri     Away
# 1  2019  11/15/19  20:00 (18:00)  FRL      Friendlies (M)  Fri     Home
# 2  2021  11/16/21  20:30 (00:30)  WCQ  WCQ — CONMEBOL (M)  Tue     Away
# 3  2021  11/16/21  20:30 (00:30)  WCQ  WCQ — CONMEBOL (M)  Tue     Away
# 4  2021   7/10/21  21:00 (02:00)   CA               Final  Sat  Neutral
#
#   Result  GF  GA  ...  Formation           Referee Coach opp_code year_code  \
# 0      D   1   1  ...        NaN     Antonio Arias  Tite        0         0
# 1      L   0   1  ...    4-1-4-1       Matt Conger  Tite        0         4
# 2      D   0   0  ...    4-2-3-1      Andrés Cunha  Tite        0         6
# 3      D   0   0  ...    4-2-3-1      Andrés Cunha  Tite        0         6
# 4      L   0   1  ...     4/3/03  Esteban Ostojich  Tite        0         6
#
#   kind_code target GF_rolling  GA_rolling  GD_rolling
# 0         3      0        3.0         0.0         3.0
# 1         1      0        1.0         1.0         0.0
# 2         3      0        0.0         1.0        -1.0
# 3         3      0        0.0         0.0         0.0
# 4         0      0        0.0         0.0         0.0
#
# [5 rows x 25 columns]

# %%
def make_prediction (matches, predictors):
  train = matches[matches['Year'] < 2020]
  test = matches[matches['Year'] >= 2021]
  rf.fit(train[predictors],train['target'])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual = test['target'], prediction = preds), index=test.index)
  precision = precision_score(test['target'], preds)
  return combined, precision

# %%
combined, precision = make_prediction(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6818181818181818

# %%
combined = combined.merge(matches_rolling[['Year','Date','GF','GA','Opponent','Coach','Result','Comp']], left_index=True, right_index=True)

combined.head()
# Out:
#    actual  prediction  Year      Date  GF  GA Opponent Coach Result Comp
# 2       0           0  2021  11/16/21   0   0      ARG  Tite      D  WCQ
# 3       0           1  2021  11/16/21   0   0      ARG  Tite      D  WCQ
# 4       0           1  2021   7/10/21   0   1      ARG  Tite      L   CA
# 6       0           1  2021    9/5/21   0   0      ARG  Tite      D  WCQ
# 7       0           1  2021    9/5/21   0   0      ARG  Tite      D  WCQ

# %% [markdown]
# ### Predicting the Future Matches

# %%
future = future_matches
future.head()
# Out:
#    Year  Date  Time Comp        Round  Day    Venue  Result  GF  GA  GD  KTPM  \
# 0  2022   NaN   NaN  FWC  Semi-finals  NaN  Neutral     NaN NaN NaN NaN   NaN
# 1  2022   NaN   NaN  FWC        Final  NaN  Neutral     NaN NaN NaN NaN   NaN
# 2  2023   NaN   NaN  FRL     Friendly  NaN     Away     NaN NaN NaN NaN   NaN
#
#   Opponent  Attendance  Captain  Formation  Referee Coach
# 0      ARG         NaN      NaN        NaN      NaN  Tite
# 1      FRA         NaN      NaN        NaN      NaN  Tite
# 2      MAR         NaN      NaN        NaN      NaN   New

# %%
future['isFuture'] = True
matches['isFuture'] = False
matches_and_future = pd.concat([matches, future])
matches_and_future
# Out:
#     Year      Date           Time Comp               Round  Day    Venue  \
# 0   2020   10/9/20  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri     Home
# 1   2020  10/13/20  19:00 (02:00)  WCQ  WCQ — CONMEBOL (M)  Tue     Away
# 2   2020  11/13/20  21:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Fri     Home
# 3   2020  11/17/20  20:00 (00:00)  WCQ  WCQ — CONMEBOL (M)  Tue     Away
# 4   2021    6/4/21  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri     Home
# ..   ...       ...            ...  ...                 ...  ...      ...
# 90  2018  11/16/18  20:00 (21:00)  FRL      Friendlies (M)  Fri     Home
# 91  2018  11/20/18  19:30 (20:30)  FRL      Friendlies (M)  Tue     Home
# 0   2022       NaN            NaN  FWC         Semi-finals  NaN  Neutral
# 1   2022       NaN            NaN  FWC               Final  NaN  Neutral
# 2   2023       NaN            NaN  FRL            Friendly  NaN     Away
#
#    Result   GF   GA  ...  Attendance       Captain Formation          Referee  \
# 0       W  5.0  0.0  ...         NaN      Casemiro    4/3/03  Leodán González
# 1       W  4.0  2.0  ...         NaN  Thiago Silva    4/3/03   Julio Bascuñán
# 2       W  1.0  0.0  ...         NaN  Thiago Silva    4/3/03     Juan Benítez
# 3       W  2.0  0.0  ...         NaN  Thiago Silva    4/3/03    Roberto Tobar
# 4       W  2.0  0.0  ...         NaN      Casemiro    4/3/03   Alexis Herrera
# ..    ...  ...  ...  ...         ...           ...       ...              ...
# 90      W  1.0  0.0  ...         NaN        Neymar    4/3/03     Craig Pawson
# 91      W  1.0  0.0  ...         NaN        Neymar   4-1-4-1   Michael Oliver
# 0     NaN  NaN  NaN  ...         NaN           NaN       NaN              NaN
# 1     NaN  NaN  NaN  ...         NaN           NaN       NaN              NaN
# 2     NaN  NaN  NaN  ...         NaN           NaN       NaN              NaN
#
#    Coach opp_code year_code kind_code  target  isFuture
# 0   Tite      3.0       5.0       3.0     1.0     False
# 1   Tite     21.0       5.0       3.0     1.0     False
# 2   Tite     31.0       5.0       3.0     1.0     False
# 3   Tite     29.0       5.0       3.0     1.0     False
# 4   Tite     10.0       6.0       3.0     1.0     False
# ..   ...      ...       ...       ...     ...       ...
# 90  Tite     29.0       3.0       1.0     1.0     False
# 91  Tite      4.0       3.0       1.0     1.0     False
# 0   Tite      NaN       NaN       NaN     NaN      True
# 1   Tite      NaN       NaN       NaN     NaN      True
# 2    New      NaN       NaN       NaN     NaN      True
#
# [95 rows x 23 columns]

# %%
matches_and_future['opp_code'] = matches_and_future['Opponent'].astype('category').cat.codes
matches_and_future['year_code'] = matches_and_future['Year'].astype('category').cat.codes
matches_and_future['kind_code'] = matches_and_future['Comp'].astype('category').cat.codes
matches_and_future['target'] = (matches_and_future['Result'] == 'W').astype('int')

# %%
matches_and_future.dtypes
# Out:
# Year            int64
# Date           object
# Time           object
# Comp           object
# Round          object
# Day            object
# Venue          object
# Result         object
# GF            float64
# GA            float64
# GD            float64
# KTPM           object
# Opponent       object
# Attendance     object
# Captain        object
# Formation      object
# Referee        object
# Coach          object
# opp_code         int8
# year_code        int8
# kind_code        int8
# target          int64
# isFuture         bool
# dtype: object

# %%
#Checking out DF
matches_and_future.head()
# Out:
#    Year      Date           Time Comp               Round  Day Venue Result  \
# 0  2020   10/9/20  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 1  2020  10/13/20  19:00 (02:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 2  2020  11/13/20  21:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
# 3  2020  11/17/20  20:00 (00:00)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
# 4  2021    6/4/21  21:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Fri  Home      W
#
#     GF   GA  ...  Attendance       Captain Formation          Referee Coach  \
# 0  5.0  0.0  ...         NaN      Casemiro    4/3/03  Leodán González  Tite
# 1  4.0  2.0  ...         NaN  Thiago Silva    4/3/03   Julio Bascuñán  Tite
# 2  1.0  0.0  ...         NaN  Thiago Silva    4/3/03     Juan Benítez  Tite
# 3  2.0  0.0  ...         NaN  Thiago Silva    4/3/03    Roberto Tobar  Tite
# 4  2.0  0.0  ...         NaN      Casemiro    4/3/03   Alexis Herrera  Tite
#
#   opp_code year_code kind_code  target  isFuture
# 0        3         5         3       1     False
# 1       23         5         3       1     False
# 2       33         5         3       1     False
# 3       31         5         3       1     False
# 4       10         6         3       1     False
#
# [5 rows x 23 columns]

# %%
#Filtering to see only FWC matches
matches_and_future[(matches_and_future['Comp'] == 'FWC')]
# Out:
#     Year      Date           Time Comp           Round  Day    Venue Result  \
# 22  2022  11/24/22  22:00 (20:00)  FWC     Group stage  Thu  Neutral      W
# 23  2022  11/28/22  19:00 (17:00)  FWC     Group stage  Mon  Neutral      W
# 24  2022   12/2/22  22:00 (20:00)  FWC     Group stage  Fri  Neutral      L
# 25  2022   12/5/22  22:00 (20:00)  FWC     Round of 16  Mon  Neutral      W
# 26  2022   12/9/22  18:00 (16:00)  FWC  Quarter-finals  Fri  Neutral      D
# 82  2018   6/17/18  21:00 (20:00)  FWC     Group stage  Sun  Neutral      D
# 83  2018   6/22/18  15:00 (14:00)  FWC     Group stage  Fri  Neutral      W
# 84  2018   6/27/18  21:00 (20:00)  FWC     Group stage  Wed  Neutral      W
# 85  2018    7/2/18  18:00 (16:00)  FWC     Round of 16  Mon  Neutral      W
# 86  2018    7/6/18  21:00 (20:00)  FWC  Quarter-finals  Fri  Neutral      L
# 0   2022       NaN            NaN  FWC     Semi-finals  NaN  Neutral    NaN
# 1   2022       NaN            NaN  FWC           Final  NaN  Neutral    NaN
#
#      GF   GA  ...  Attendance       Captain Formation          Referee Coach  \
# 22  2.0  0.0  ...      88,103  Thiago Silva   4-2-3-1  Alireza Faghani  Tite
# 23  1.0  0.0  ...      43,649  Thiago Silva    4/3/03      Iván Barton  Tite
# 24  0.0  1.0  ...      85,986    Dani Alves   4-2-3-1    Ismail Elfath  Tite
# 25  4.0  1.0  ...      43,847  Thiago Silva   4-2-3-1   Clément Turpin  Tite
# 26  1.0  1.0  ...      43,893  Thiago Silva   4-2-3-1   Michael Oliver  Tite
# 82  1.0  1.0  ...      43,109       Marcelo    4/3/03      César Ramos  Tite
# 83  2.0  0.0  ...      64,468  Thiago Silva    4/3/03    Björn Kuipers  Tite
# 84  2.0  0.0  ...      44,190       Miranda    4/3/03  Alireza Faghani  Tite
# 85  2.0  0.0  ...      41,970  Thiago Silva    4/3/03  Gianluca Rocchi  Tite
# 86  1.0  2.0  ...      42,873       Miranda    4/3/03    Milorad Mažić  Tite
# 0   NaN  NaN  ...         NaN           NaN       NaN              NaN  Tite
# 1   NaN  NaN  ...         NaN           NaN       NaN              NaN  Tite
#
#    opp_code year_code kind_code  target  isFuture
# 22       28         7         2       1     False
# 23       29         7         2       1     False
# 24        4         7         2       0     False
# 25       16         7         2       1     False
# 26        8         7         2       0     False
# 82       29         3         2       0     False
# 83        7         3         2       1     False
# 84       28         3         2       1     False
# 85       19         3         2       1     False
# 86        2         3         2       0     False
# 0         0         7         2       0      True
# 1        11         7         2       0      True
#
# [12 rows x 23 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches_and_future[matches_and_future['Year'] < 2021]
test = matches_and_future[matches_and_future['Year'] >= 2022]
predictors = ['kind_code','year_code','opp_code']

# %%
rf.fit(train[predictors],train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test['target'], preds)
# Out:
# 0.625

# %%
combined = pd.DataFrame(dict(actual = test['target'], prediction = preds))

pd. crosstab(index=combined['actual'], columns = combined['prediction'])
# Out:
# prediction   1
# actual
# 0            6
# 1           10

# %%
from sklearn.metrics import precision_score

precision_score(test['target'], preds)
# Out:
# 0.625

# %%
grouped_matches = matches_and_future.groupby('Coach')
group = grouped_matches.get_group('Tite').sort_values('Date')

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values('Date')
  rolling_stats = group[cols].rolling(1, closed='left').mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group
  
cols = ['opp_code','kind_code']
new_cols = [f'{c}_rolling' for c in cols]

# %%
rolling_averages(group, cols, new_cols).head()
# Out:
#     Year      Date           Time Comp               Round  Day Venue Result  \
# 77  2017  10/10/17  20:30 (01:30)  WCQ  WCQ — CONMEBOL (M)  Tue  Home      W
# 56  2019  10/10/19  20:00 (14:00)  FRL      Friendlies (M)  Thu  Home      D
# 10  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 40  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 69  2016  10/11/16  20:30 (02:30)  WCQ  WCQ — CONMEBOL (M)  Tue  Away      W
#
#      GF   GA  ...  Formation                Referee Coach opp_code year_code  \
# 77  3.0  0.0  ...        NaN             Juan Bravo  Tite        5         2
# 56  1.0  1.0  ...    4-2-2-2  Taqi Aljaafari Jahari  Tite       26         4
# 10  0.0  0.0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 40  0.0  0.0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 69  2.0  0.0  ...        NaN        Víctor Carrillo  Tite       33         1
#
#    kind_code target isFuture  opp_code_rolling  kind_code_rolling
# 77         3      1    False              10.0                3.0
# 56         1      0    False               5.0                3.0
# 10         3      0    False              26.0                1.0
# 40         3      0    False               6.0                3.0
# 69         3      1    False               6.0                3.0
#
# [5 rows x 25 columns]

# %%
matches_rolling = matches_and_future.groupby('Result').apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('Result')
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling.head()
# Out:
#    Year      Date           Time Comp               Round  Day Venue Result  \
# 0  2019  10/10/19  20:00 (14:00)  FRL      Friendlies (M)  Thu  Home      D
# 1  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 2  2021  10/10/21  16:00 (23:00)  WCQ  WCQ — CONMEBOL (M)  Sun  Away      D
# 3  2019  10/13/19  20:00 (14:00)  FRL      Friendlies (M)  Sun  Home      D
# 4  2017   10/5/17  16:00 (22:00)  WCQ  WCQ — CONMEBOL (M)  Thu  Away      D
#
#     GF   GA  ...  Formation                Referee Coach opp_code year_code  \
# 0  1.0  1.0  ...    4-2-2-2  Taqi Aljaafari Jahari  Tite       26         4
# 1  0.0  0.0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 2  0.0  0.0  ...    4-2-3-1       Patricio Loustau  Tite        6         6
# 3  1.0  1.0  ...    4-2-3-1             Jansen Foo  Tite       20         4
# 4  0.0  0.0  ...        NaN     Fernando Rapallini  Tite        3         2
#
#   kind_code target isFuture  opp_code_rolling  kind_code_rolling
# 0         1      0    False              10.0                3.0
# 1         3      0    False              26.0                1.0
# 2         3      0    False               6.0                3.0
# 3         1      0    False               6.0                3.0
# 4         3      0    False              20.0                1.0
#
# [5 rows x 25 columns]

# %%
def make_prediction(matches_and_future, predictors):
    train = matches_and_future[matches_and_future['Year'] < 2020]
    test = matches_and_future[matches_and_future['Year'] >= 2021]
    rf.fit(train[predictors], train['target'])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], prediction=preds), index=test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision = make_prediction(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.8888888888888888

# %%
combined = combined.merge(matches_rolling[['Year','Date','GF','GA','Opponent','Result','Comp']], left_index=True, right_index=True)

opp = combined[(combined['Comp'] == 'FWC')]
opp.sort_values(by=['Year'], ascending = False)
# Out:
#     actual  prediction  Year      Date   GF   GA Opponent Result Comp
# 8        0           0  2022   12/9/22  1.0  1.0      CRO      D  FWC
# 21       0           0  2022   12/2/22  0.0  1.0      CAM      L  FWC
# 45       1           1  2022  11/24/22  2.0  0.0      SRB      W  FWC
# 46       1           1  2022  11/28/22  1.0  0.0      SUI      W  FWC
# 47       1           1  2022   12/5/22  4.0  1.0      KOR      W  FWC
